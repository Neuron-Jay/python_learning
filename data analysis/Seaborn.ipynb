# %% [markdown]
# ## Seaborn: 让你可以更轻松地画出更好看的图表

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


titanic=sns.load_dataset('titanic')    # 竟然还内置了一个现有的数据
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 635         1       2  female  28.0      0      0  13.0000        S  Second
# 636         0       3    male  32.0      0      0   7.9250        S   Third
# 637         0       2    male  31.0      1      1  26.2500        S  Second
# 638         0       3  female  41.0      0      5  39.6875        S   Third
# 639         0       3    male   NaN      1      0  16.1000        S     NaN
#
#        who adult_male deck  embark_town alive  alone
# ...
